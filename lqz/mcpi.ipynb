# %%
from mcpi.minecraft import Minecraft
import time
import numpy as np
import cv2
cap = cv2.VideoCapture(0)
S=0
mc=Minecraft.create()
print(1)
def checkS():
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
    while True:
        ret,img=cap.read()
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            S=w*h
            print((x,y,w,h,S))
            pos=mc.player.getTilePos()
            if S<30000:
                mc.player.setTilePos(pos.x-1,pos.y,pos.z)
                print("up")
            elif S>50000:
                mc.player.setTilePos(pos.x+1,pos.y,pos.z)
                print("down")
            if x<200:
                mc.player.setTilePos(pos.x,pos.y-1,pos.z)
                print("left")
            elif x>300:
                mc.player.setTilePos(pos.x,pos.y+1,pos.z)
                print("right")
            time.sleep(1)
            

while True:
    '''print("stay_time"+str(stayed_time))
    time.sleep(0.5)
    pos=mc.player.getTilePos()
    mc.postToChat("please go to home x=-30 y=-6 for 15s to fly")
    mc.postToChat("x:"+str(pos.x)+"y:"+str(pos.y)+"z:"+str(pos.z)) 
    if pos.x==-30  and pos.y==-6:
        mc.postToChat("welcome home")
        #playsongs()
        stayed_time=stayed_time+1
        if stayed_time>=5:
            mc.player.setTilePos(-32,9,-45)
            stayed_time=0
    else:
        stayed_time=0
    '''
    checkS()
    time.sleep(10)
# Out:
# 1
# (154, 196, 255, 255, 65025)
# down
# left
# (154, 200, 255, 255, 65025)
# down
# left
# (165, 201, 242, 242, 58564)
# down
# left
# (181, 203, 237, 237, 56169)
# down
# left
# (174, 198, 244, 244, 59536)
# down
# left
# (166, 185, 241, 241, 58081)
# down
# left
# (155, 189, 212, 212, 44944)
# left
# (162, 186, 219, 219, 47961)
# left
# (157, 182, 226, 226, 51076)
# down
# left
# (157, 185, 220, 220, 48400)
# left
# (161, 189, 210, 210, 44100)
# left
# (158, 186, 218, 218, 47524)
# left
# (158, 186, 216, 216, 46656)
# left
# (170, 189, 214, 214, 45796)
# left
# (164, 185, 220, 220, 48400)
# left
# (160, 187, 218, 218, 47524)
# left
# (158, 188, 219, 219, 47961)
# left
# (163, 191, 212, 212, 44944)
# left
# (168, 190, 205, 205, 42025)
# left
# (161, 188, 218, 218, 47524)
# left
# (156, 186, 224, 224, 50176)
# down
# left
# (160, 189, 217, 217, 47089)
# left
# (141, 193, 209, 209, 43681)
# left
# (112, 190, 230, 230, 52900)
# down
# left
# (214, 202, 205, 205, 42025)
# (194, 196, 214, 214, 45796)
# left
# (186, 191, 213, 213, 45369)
# left
# (187, 188, 215, 215, 46225)
# left
# (178, 182, 233, 233, 54289)
# down
# left
# (172, 182, 237, 237, 56169)
# down
# left
# (180, 188, 222, 222, 49284)
# left
# (179, 184, 196, 196, 38416)
# left
# (178, 186, 196, 196, 38416)
# left
# (186, 192, 187, 187, 34969)
# left
# (175, 193, 208, 208, 43264)
# left
# (181, 197, 188, 188, 35344)
# left
# (186, 200, 181, 181, 32761)
# left
# (182, 199, 191, 191, 36481)
# left
# (180, 197, 196, 196, 38416)
# left
# (174, 195, 203, 203, 41209)
# left
# (182, 196, 194, 194, 37636)
# left
# (173, 198, 196, 196, 38416)
# left
# (251, 189, 196, 196, 38416)
# (241, 201, 185, 185, 34225)
# (230, 191, 196, 196, 38416)
# (245, 213, 171, 171, 29241)
# up
# (229, 197, 188, 188, 35344)
# (223, 193, 197, 197, 38809)
# (229, 200, 188, 188, 35344)
# (223, 197, 197, 197, 38809)
# (224, 192, 198, 198, 39204)
# (220, 194, 202, 202, 40804)
# (224, 196, 194, 194, 37636)
# (215, 190, 208, 208, 43264)
# (227, 199, 184, 184, 33856)
# (225, 197, 189, 189, 35721)
# (218, 190, 206, 206, 42436)
# (222, 198, 196, 196, 38416)
# (179, 163, 280, 280, 78400)
# down
# left
# (160, 157, 306, 306, 93636)
# down
# left
# (165, 161, 298, 298, 88804)
# down
# left
# (199, 162, 235, 235, 55225)
# down
# left
# (188, 164, 239, 239, 57121)
# down
# left
# (187, 154, 241, 241, 58081)
# down
# left
# (179, 150, 253, 253, 64009)
# down
# left
# (188, 157, 236, 236, 55696)
# down
# left
# (197, 165, 221, 221, 48841)
# left
# (197, 154, 233, 233, 54289)
# down
# left
# (216, 150, 234, 234, 54756)
# down
# (216, 156, 226, 226, 51076)
# down
# (216, 155, 226, 226, 51076)
# down
# (216, 157, 227, 227, 51529)
# down
# (214, 157, 226, 226, 51076)
# down
# (213, 182, 196, 196, 38416)
# (211, 181, 196, 196, 38416)
# (213, 180, 196, 196, 38416)
# (214, 181, 185, 185, 34225)
# (210, 179, 196, 196, 38416)
# (218, 178, 196, 196, 38416)
# (200, 164, 231, 231, 53361)
# down
# (213, 184, 212, 212, 44944)
# (191, 180, 216, 216, 46656)
# left
# (165, 172, 220, 220, 48400)
# left
# (217, 176, 201, 201, 40401)
# (206, 176, 216, 216, 46656)
# (203, 169, 221, 221, 48841)
# (202, 144, 224, 224, 50176)
# down
# (216, 160, 210, 210, 44100)
# (212, 172, 203, 203, 41209)
# (212, 169, 199, 199, 39601)
# (208, 165, 211, 211, 44521)
# (212, 166, 202, 202, 40804)
# (209, 163, 210, 210, 44100)
# (207, 142, 220, 220, 48400)
# (211, 185, 200, 200, 40000)
# (166, 175, 262, 262, 68644)
# down
# left
# (193, 160, 233, 233, 54289)
# down
# left
# (198, 146, 226, 226, 51076)
# down
# left
# (207, 155, 206, 206, 42436)
# (196, 148, 230, 230, 52900)
# down
# left
# (197, 146, 234, 234, 54756)
# down
# left
# (198, 148, 228, 228, 51984)
# down
# left
# (199, 151, 229, 229, 52441)
# down
# left
# (206, 156, 215, 215, 46225)
# (216, 167, 190, 190, 36100)
# (368, 236, 69, 69, 4761)
# up
# right
# (373, 233, 76, 76, 5776)
# up
# right
# (374, 234, 72, 72, 5184)
# up
# right
# (368, 230, 82, 82, 6724)
# up
# right
# (369, 233, 75, 75, 5625)
# up
# right
# (280, 180, 183, 183, 33489)
# (197, 182, 196, 196, 38416)
# left
# (208, 181, 197, 197, 38809)
# (191, 178, 214, 214, 45796)
# left
# (189, 183, 208, 208, 43264)
# left
# (185, 178, 214, 214, 45796)
# left
# (196, 184, 198, 198, 39204)
# left
# (189, 180, 205, 205, 42025)
# left
# (191, 180, 202, 202, 40804)
# left
# (196, 183, 186, 186, 34596)
# left
# (186, 176, 205, 205, 42025)
# left
# (184, 180, 207, 207, 42849)
# left
# (194, 183, 188, 188, 35344)
# left
# (191, 181, 193, 193, 37249)
# left
# (195, 183, 188, 188, 35344)
# left
# (258, 209, 196, 196, 38416)
# (219, 192, 216, 216, 46656)
# (216, 191, 189, 189, 35721)
# (210, 189, 198, 198, 39204)
# (206, 187, 203, 203, 41209)
# (201, 178, 198, 198, 39204)
# (216, 167, 207, 207, 42849)
# (164, 119, 284, 284, 80656)
# down
# left
# (224, 127, 188, 188, 35344)
# (225, 131, 190, 190, 36100)
# (263, 199, 151, 151, 22801)
# up
# (264, 237, 134, 134, 17956)
# up
# (265, 252, 116, 116, 13456)
# up
# (267, 253, 116, 116, 13456)
# up
# (264, 251, 122, 122, 14884)
# up
# (265, 252, 121, 121, 14641)
# up
# (231, 200, 177, 177, 31329)
# (231, 171, 196, 196, 38416)
# (201, 176, 204, 204, 41616)
# (194, 176, 216, 216, 46656)
# left
# (203, 170, 213, 213, 45369)
# (203, 174, 205, 205, 42025)
# (200, 175, 209, 209, 43681)
# (197, 169, 214, 214, 45796)
# left
# (202, 179, 206, 206, 42436)
# (200, 171, 211, 211, 44521)
# (204, 178, 197, 197, 38809)
# (184, 165, 243, 243, 59049)
# down
# left
# (160, 159, 280, 280, 78400)
# down
# left
# (160, 159, 272, 272, 73984)
# down
# left
# (162, 163, 267, 267, 71289)
# down
# left
# (190, 155, 221, 221, 48841)
# left
# (216, 152, 211, 211, 44521)
# (200, 145, 226, 226, 51076)
# down
# (224, 149, 212, 212, 44944)
# (214, 148, 222, 222, 49284)
# (212, 157, 217, 217, 47089)
# (214, 156, 214, 214, 45796)
# (208, 150, 221, 221, 48841)
# (208, 151, 223, 223, 49729)
# (221, 162, 208, 208, 43264)
# (216, 156, 214, 214, 45796)
# (221, 163, 213, 213, 45369)
# (223, 165, 210, 210, 44100)
# (208, 155, 221, 221, 48841)
# (219, 164, 207, 207, 42849)
# (219, 161, 213, 213, 45369)
# (226, 164, 209, 209, 43681)
# (222, 164, 211, 211, 44521)
# (227, 164, 207, 207, 42849)
# (236, 171, 203, 203, 41209)
# (226, 159, 222, 222, 49284)
# (230, 160, 221, 221, 48841)
# (248, 177, 183, 183, 33489)
# (242, 169, 199, 199, 39601)
# (241, 175, 201, 201, 40401)
# (244, 172, 201, 201, 40401)
# (247, 179, 196, 196, 38416)
# (246, 177, 196, 196, 38416)
# (242, 171, 211, 211, 44521)
# (236, 168, 214, 214, 45796)
# (242, 170, 207, 207, 42849)
# (240, 169, 211, 211, 44521)
# (247, 177, 195, 195, 38025)
# (247, 172, 205, 205, 42025)
# (246, 170, 208, 208, 43264)
# (248, 171, 201, 201, 40401)
# (247, 173, 207, 207, 42849)
# (246, 175, 202, 202, 40804)
# (232, 169, 212, 212, 44944)
# (229, 173, 204, 204, 41616)
# (234, 177, 207, 207, 42849)
# (244, 177, 196, 196, 38416)
# (242, 179, 196, 196, 38416)
# (240, 174, 201, 201, 40401)
# (240, 178, 196, 196, 38416)
# (244, 175, 196, 196, 38416)
# (240, 175, 197, 197, 38809)
# (185, 147, 255, 255, 65025)
# down
# left
# (199, 162, 196, 196, 38416)
# left
# (223, 174, 174, 174, 30276)
# (213, 171, 190, 190, 36100)
# (226, 178, 183, 183, 33489)
# (235, 180, 178, 178, 31684)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-74a405d564ac> in <module>
#      49         stayed_time=0
#      50     '''
# ---> 51     checkS()
#      52     time.sleep(10)
#
# <ipython-input-4-74a405d564ac> in checkS()
#      30                 mc.player.setTilePos(pos.x,pos.y+1,pos.z)
#      31                 print("right")
# ---> 32             time.sleep(1)
#      33
#      34
#
# KeyboardInterrupt:
